# %%
import os
import requests
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver

# %% [markdown]
# MISSION TO MARS

# %%
UrlNews = 'https://mars.nasa.gov/news/'
ExecutablePath = {'executable_path': "/usr/local/bin/chromedriver}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(url_news)
html = browser.html
NewsMars = BeautifulSoup(html, 'lxml')
print(NewsMars.prettify())
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1c6c66dcdd13> in <module>
#       1 UrlNews = 'https://mars.nasa.gov/news/'
#       2 ExecutablePath = {'executable_path': "/usr/local/bin/chromedriver"}
# ----> 3 browser = Browser('chrome', **executable_path, headless=False)
#       4 browser.visit(url_news)
#       5 html = browser.html
#
# NameError: name 'executable_path' is not defined

# %%
NewsTitle = NewsMars.find('div','content_title').text
print(NewsTitle)
# Out:
# Mars Now

# %%
NewsParagraph = NewsMars.find('div','rollover_description_inner').text
print(NewsParagraph)
# Out:
# A mission to investigate key questions about potential life on Mars.

# %% [markdown]
# JPL MARS SPACE IMAGES - FEATURADED IMAGE

# %%
UrlJpl = 'https://www.jpl.nasa.gov'
UrlJplImages = 'https://www.jpl.nasa.gov/spaceimages/?search=planet&category=Mars'
ExecutablePath2 = {'executable_path': "/usr/local/bin/chromedriver"}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(url_jpl_images)
html = browser.html
JplSoup = BeautifulSoup(html, 'lxml')
image = JplSoup.find_all('img', class_='thumb')[30]['src']
ImageUrl = UrlJpl + image
print(ImageUrl)
browser.quit()
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA22487-640x350.jpg

# %% [markdown]
# MARS WEATHER

# %%
UrlTWTR = 'https://twitter.com/marswxreport?lang=en'
ExecutablePath3 = {'executable_path': "/usr/local/bin/chromedriver"}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(URLTWTR)
html = browser.html
TWTRSoup = BeautifulSoup(html, 'lxml')
print(TWTRSoup.prettify())
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-48c400d2ea45> in <module>
#       1 UrlTWTR = 'https://twitter.com/marswxreport?lang=en'
#       2 ExecutablePath3 = {'executable_path': "/usr/local/bin/chromedriver"}
# ----> 3 browser = Browser('chrome', **executable_path, headless=False)
#       4 browser.visit(URLTWTR)
#       5 html = browser.html
#
# NameError: name 'Browser' is not defined

# %%
MarsTWTR = TWTRSoup.find_all('span', class_='css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0')[27].text
print(MarsTWTR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-33cabe6dbfea> in <module>
# ----> 1 MarsTWTR = TWTRSoup.find_all('span', class_='css-901oao css-16my406 r-1qd0xha r-ad9z0x r-bcqeeo r-qvutc0')[27].text
#       2 print(MarsTWTR)
#
# NameError: name 'TWTRSoup' is not defined

# %% [markdown]
# MARS FACTS

# %%
UrlFacts = 'https://space-facts.com/mars/'
ExecutablePath4 = {'executable_path': "/usr/local/bin/chromedriver"}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(UrlFacts)
html = browser.html
FactsMars = BeautifulSoup(html, 'lxml')
print(FactsMars.prettify())
browser.quit()
# Out:
# <html lang="en-US">
#  <head>
#   <script src="https://partner.googleadservices.com/gampad/cookie.js?domain=space-facts.com&amp;callback=_gfp_s_&amp;client=ca-pub-4251889121233823">
#   </script>
#   <script id="google_shimpl" src="https://pagead2.googlesyndication.com/pagead/js/r20200817/r20190131/show_ads_impl_fy2019.js">
#   </script>
#   <script async="" src="https://graph.facebook.com/?callback=WPCOMSharing.update_facebook_count&amp;ids=https%3A%2F%2Fspace-facts.com%2Fmars%2F&amp;_=1597803593839">
#   </script>
#   <script async="" src="https://api.pinterest.com/v1/urls/count.json?callback=WPCOMSharing.update_pinterest_count&amp;url=https%3A%2F%2Fspace-facts.com%2Fmars%2F&amp;_=1597803593838">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://space-facts.com/wp/xmlrpc.php" rel="pingback"/>
#   <script>
# ...

# %%
TableOfFacts = pd.read_html(UrlFacts)
MarsInfo = TableOfFacts[0]
MarsInfo = MarsInfo.rename(columns={0: 'Description',1: 'Value'})
MarsInfo
# Out:
#             Description                          Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
MarsInfo.to_html('MarsInfoTable.html')

# %% [markdown]
# MARS HEMISPHERES

# %%
ExecutablePath5 = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)
url = "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
browser.visit(url)

# %%
HemisphereImageUrls = []

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e5796e668ac> in <module>
# ----> 1 scrape_mars.py
#
# NameError: name 'scrape_mars' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-3-ac636948a7d6> in <module>
#       1 url = "https://mars.nasa.gov/news/"
# ----> 2 browser.visit(url)
#
# /opt/anaconda3/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py in visit(self, url)
#     320
#     321     def visit(self, url):
# --> 322         self.driver.get(url)
#     323
#     324     def back(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
# Out:
# Python 3.7.6
